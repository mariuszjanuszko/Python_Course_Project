# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# New Column 'job_posted_month'
df['job_posted_month']= df['job_posted_date'].dt.to_period('M')

# %% [markdown]
# 🟩 Merge US Jobs and Monthly Postings (2.7.1) - Problem
# Pandas Merge DataFrames
# Problem Statement:
#
#     Create a DataFrame df_us_jobs that contains only job postings in the United States.
#     Then, create another DataFrame df_monthly_postings that counts the number of U.S. job postings for each month.
#     Merge these two DataFrames on the job_posted_month column using a right join, and display the first 5 rows of the resulting DataFrame.
#
# Hint:
#
#     Filter the DataFrame first then use the groupby() method to count the number of job postings for each month.
#     Use the merge() function to combine the DataFrames on the job_posted_month column.

# %%
df_us_jobs = df[df['job_country']=='United States']
df_monthly_postings = df_us_jobs.groupby('job_posted_month').size().reset_index(name='count')
df_us_jobs.merge(df_monthly_postings ,on='job_posted_month',how ='right').head()
# Out:
#     job_title_short                     job_title    job_location  \
# 0     Data Engineer                 Data Engineer  Fort Worth, TX
# 1     Data Engineer                 Data Engineer   San Mateo, CA
# 2  Business Analyst  Business Intelligence Intern      Dallas, TX
# 3     Data Engineer                 Data Engineer  Cincinnati, OH
# 4      Data Analyst                  Data Analyst       Tampa, FL
#
#            job_via job_schedule_type  job_work_from_home  \
# 0     via LinkedIn         Full-time               False
# 1     via LinkedIn         Full-time               False
# 2     via LinkedIn         Full-time               False
# 3  via SimplyHired         Full-time               False
# 4     via LinkedIn         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# 0       Texas, United States 2023-01-25 13:24:01                  False
# 1  California, United States 2023-01-28 13:07:30                  False
# 2       Texas, United States 2023-01-04 13:02:07                  False
# 3       Texas, United States 2023-01-22 13:08:53                  False
# 4     Florida, United States 2023-01-19 13:19:45                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                  True  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                 company_name  \
# 0              NaN               Programmers.io
# 1              NaN                      Verkada
# 2              NaN                       Copart
# 3              NaN  Divisions Maintenance Group
# 4              NaN                         Citi
#
#                                           job_skills  \
# 0                                  ['sql', 'python']
# 1                 ['sql', 'python', 'aws', 'looker']
# 2      ['r', 'python', 'sql', 'tableau', 'power bi']
# 3  ['sql', 'nosql', 'python', 'java', 'c++', 'sca...
# 4         ['sql', 'python', 'unix', 'excel', 'jira']
#
#                                      job_type_skills job_posted_month  count
# 0                 {'programming': ['sql', 'python']}          2023-01  22670
# 1  {'analyst_tools': ['looker'], 'cloud': ['aws']...          2023-01  22670
# 2  {'analyst_tools': ['tableau', 'power bi'], 'pr...          2023-01  22670
# 3  {'databases': ['cassandra'], 'libraries': ['ha...          2023-01  22670
# 4  {'analyst_tools': ['excel'], 'async': ['jira']...          2023-01  22670

# %%
df['job_posted_month'] = df['job_posted_date'].dt.to_period('M')
df_us_jobs = df[df['job_country'] == 'United States']
df_monthly_postings = df_us_jobs.groupby('job_posted_month').size().reset_index(name='postings_count')
merged_df = pd.merge(df_us_jobs, df_monthly_postings, on='job_posted_month', how='right')
merged_df.head()
# Out:
#     job_title_short                     job_title    job_location  \
# 0     Data Engineer                 Data Engineer  Fort Worth, TX
# 1     Data Engineer                 Data Engineer   San Mateo, CA
# 2  Business Analyst  Business Intelligence Intern      Dallas, TX
# 3     Data Engineer                 Data Engineer  Cincinnati, OH
# 4      Data Analyst                  Data Analyst       Tampa, FL
#
#            job_via job_schedule_type  job_work_from_home  \
# 0     via LinkedIn         Full-time               False
# 1     via LinkedIn         Full-time               False
# 2     via LinkedIn         Full-time               False
# 3  via SimplyHired         Full-time               False
# 4     via LinkedIn         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# 0       Texas, United States 2023-01-25 13:24:01                  False
# 1  California, United States 2023-01-28 13:07:30                  False
# 2       Texas, United States 2023-01-04 13:02:07                  False
# 3       Texas, United States 2023-01-22 13:08:53                  False
# 4     Florida, United States 2023-01-19 13:19:45                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                  True  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                 company_name  \
# 0              NaN               Programmers.io
# 1              NaN                      Verkada
# 2              NaN                       Copart
# 3              NaN  Divisions Maintenance Group
# 4              NaN                         Citi
#
#                                           job_skills  \
# 0                                  ['sql', 'python']
# 1                 ['sql', 'python', 'aws', 'looker']
# 2      ['r', 'python', 'sql', 'tableau', 'power bi']
# 3  ['sql', 'nosql', 'python', 'java', 'c++', 'sca...
# 4         ['sql', 'python', 'unix', 'excel', 'jira']
#
#                                      job_type_skills job_posted_month  \
# 0                 {'programming': ['sql', 'python']}          2023-01
# 1  {'analyst_tools': ['looker'], 'cloud': ['aws']...          2023-01
# 2  {'analyst_tools': ['tableau', 'power bi'], 'pr...          2023-01
# 3  {'databases': ['cassandra'], 'libraries': ['ha...          2023-01
# 4  {'analyst_tools': ['excel'], 'async': ['jira']...          2023-01
#
#    postings_count
# 0           22670
# 1           22670
# 2           22670
# 3           22670
# 4           22670

# %% [markdown]
# 🟨 Merge Non-Remote Jobs and Salary (2.7.2) - Problem
# Pandas Merge DataFrames
# Problem Statement:
#
#     Create a DataFrame df_not_remote_jobs that contains only job postings that do not offer remote work (job_work_from_home == False).
#
#     From df_not_remote_jobs, calculate the average yearly salary (salary_year_avg) for each job title (job_title_short).
#     Store the result in a new DataFrame df_not_remote_salary.
#     Rename the salary column to salary_not_remote_avg.
#
#     Merge df_not_remote_jobs and df_not_remote_salary on the job_title_short column using a right join.
#
#     Display the first 5 rows of the resulting DataFrame.
#
# Hint:
#
# Filter the DataFrame first to get non-remote jobs. Then use the groupby() method to calculate the average salary for these non-remote jobs. Use the merge() function to combine the DataFrames on the job_title_short column.

# %%
df_not_remote_jobs = df[df['job_work_from_home'] == False]
df_not_remote_salary = df_not_remote_jobs.groupby('job_title_short',as_index=False)['salary_year_avg'].mean()
df_not_remote_salary.rename(columns={'salary_year_avg': 'salary_not_remote_avg'}, inplace= True)
pd.merge(df_not_remote_jobs, df_not_remote_salary, on='job_title_short', how='right').head()
# Out:
#     job_title_short                                 job_title  \
# 0  Business Analyst  Technology & Operations Business Analyst
# 1  Business Analyst              Business Intelligence Intern
# 2  Business Analyst                               BI Engineer
# 3  Business Analyst                          Business Analyst
# 4  Business Analyst                        Commercial Analyst
#
#             job_location             job_via job_schedule_type  \
# 0    Copenhagen, Denmark     via Trabajo.org         Full-time
# 1             Dallas, TX        via LinkedIn         Full-time
# 2                Namibia  via Intellijobs.ai         Full-time
# 3  Tel Aviv-Yafo, Israel          via Comeet         Full-time
# 4           South Africa        via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False               Denmark 2023-06-05 13:44:34
# 1               False  Texas, United States 2023-01-04 13:02:07
# 2               False               Namibia 2023-03-05 14:10:49
# 3               False                Israel 2023-09-05 13:50:12
# 4               False          South Africa 2023-02-14 13:36:23
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False        Denmark        None
# 1                  False                 False  United States        None
# 2                  False                 False        Namibia        None
# 3                  False                 False         Israel        None
# 4                   True                 False   South Africa        None
#
#    salary_year_avg  salary_hour_avg company_name  \
# 0              NaN              NaN       Hempel
# 1              NaN              NaN       Copart
# 2              NaN              NaN      Innover
# 3              NaN              NaN   ironSource
# 4              NaN              NaN          PEP
#
#                                       job_skills  \
# 0            ['excel', 'powerpoint', 'power bi']
# 1  ['r', 'python', 'sql', 'tableau', 'power bi']
# 2            ['sql', 'gcp', 'looker', 'tableau']
# 3                               ['sql', 'excel']
# 4              ['sql', 'tableau', 'spss', 'sap']
#
#                                      job_type_skills job_posted_month  \
# 0  {'analyst_tools': ['excel', 'powerpoint', 'pow...          2023-06
# 1  {'analyst_tools': ['tableau', 'power bi'], 'pr...          2023-01
# 2  {'analyst_tools': ['looker', 'tableau'], 'clou...          2023-03
# 3  {'analyst_tools': ['excel'], 'programming': ['...          2023-09
# 4  {'analyst_tools': ['tableau', 'spss', 'sap'], ...          2023-02
#
#    salary_not_remote_avg
# 0            90177.41994
# 1            90177.41994
# 2            90177.41994
# 3            90177.41994
# 4            90177.41994

# %% [markdown]
# 🟨 Merge Company Salary and Remote Count (2.7.3) - Problem
# Pandas Merge DataFrames
# Problem Statement:
#
#     Create a DataFrame df_company_salary that calculates the average yearly salary for each company.
#     Then, create another DataFrame df_company_remote that counts the number of remote job postings for each company. Name this count column remote_count.
#     Merge these two DataFrames on the company_name column using an inner join and display the first 5 rows of the resulting DataFrame.
#
# Hint:
#
# Calculate the average yearly salary by company_name. Then use the groupby() function to calculate the average salary and count the number of remote job postings for each company. Use the merge() function to combine the DataFrames on the company_name column.

# %%
df_company_salary = df.groupby('company_name',as_index=False)['salary_year_avg'].mean()
df_company_salary.dropna(subset='salary_year_avg',inplace=True)
df_company_remote = df[df['job_work_from_home'] == True].groupby('company_name', as_index=False)['job_work_from_home'].count()
df_company_remote.rename(columns={'job_work_from_home': 'remote_count'},inplace=True)
df_company_salary.merge(df_company_remote, on='company_name').head(5)
# Out:
#               company_name  salary_year_avg  remote_count
# 0  #twiceasnice Recruiting     77750.000000             1
# 1            0nward Select     92500.000000             1
# 2           1 Point System    137290.484375             1
# 3      1 Point System LLC.    170000.000000             1
# 4          1872 Consulting    143333.333333             2
