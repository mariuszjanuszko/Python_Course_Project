# %% [markdown]
# 🟩 Job Postings Count (1.2.1) - Problem
# Variables
# Problem Statement:
#
# Create a variable, called job_count to store the number 42. Print job_count once calculated.
# Hint:
#
# Use the assignment operator = to assign the value to the variable.

# %%
job_count = 42
print(job_count)
# Out:
# 42

# %% [markdown]
# 🟩 Store Job Information (1.2.2) - Problem
# Variables
# Problem Statement:
#
# Create variables to store the job title, company name, and whether the job is remote for a Data Engineer position. Set the job title to 'Data Engineer', the company name to 'DataWorks', and the remote status to True. Print all the variables.
# Hint:
#
# Use the assignment operator = to assign values to the variables.

# %%
job_title = "Data Engineer"
company_name = "DataWorks"
is_remote = True
print(f'{"Job:".ljust(15)} {job_title}\n{"Company:".ljust(15)} {company_name}\n{"Remote work:".ljust(15)} {"Yes" if is_remote else "No"}')
# Out:
# Job:            Data Engineer
# Company:        DataWorks
# Remote work:    Yes

# %% [markdown]
# 🟨 Calculate Total Compensation (1.2.3) - Problem
# Variables
# Problem Statement:
#
# Calculate the total compensation for a Data Scientist by adding two variables of base_salary and bonus. The base salary is 120000 and the bonus is 20000. Store the result in a variable named total_compensation. Print total_compensation once calculated.
# Hint:
#
# Use the + operator to add the base salary and bonus.

# %%
base_salary = 120000
bonus = 20000
total_compensation = base_salary + bonus
print(total_compensation)
# Out:
# 140000

# %% [markdown]
# 🟨 Calculate Monthly Salary (1.2.4) - Problem
# Variables
# Problem Statement:
#
# Calculate the monthly salary of a Data Analyst job by dividing the annual salary of $72K by 12 and then printing the monthly salary. Assign appropriate variable names for each.
# Hint:
#
# Use the / operator to divide the annual salary by 12.

# %%
annual_salary = 72000
monthly_salary = annual_salary // 12
print(monthly_salary)
# Out:
# 6000

# %% [markdown]
# 🟥 Calculate Total Compensation with Bonus (1.2.5) - Problem
# Variables
# Problem Statement:
#
# Create variables to store the job title, company name, and salary for a Data Scientist position at AI Solutions for $110K. Then, calculate the total compensation by adding a 10% bonus to the salary and print the total compensation, along with the job and company name.
# Hint:
#
# Use the * operator to calculate the 10% bonus and the + operator to add it to the salary.

# %%
job_title = "Data Scientist"
company_name = "AI Solutions"
salary = 110000
bonus = 0.1
total_compensation = salary + (salary * bonus)
"""
bonus = salary * 0.1
total_compensation = salary + bonus
"""
print(f'Job: {job_title}\nCompany: {company_name}\nTotal Compensation: {total_compensation}')
# Out:
# Job: Data Scientist
# Company: AI Solutions
# Total Compensation: 121000.0

# %% [markdown]
# 🟩 Check Data Type (1.3.1) - Problem
# Data Types
# Problem Statement:
#
# Check the data type of the variable job_title which is set to 'Data Scientist' (Note: 'Data Scientist' is in quotes).
# Code Needed:
#
# job_title = 'Data Scientist'
#
# Hint:
#
# Use the type() function to check the data type of a variable.

# %%
job_title = 'Data Scientist'

print(type(job_title))
# Out:
# <class 'str'>

# %% [markdown]
# 🟩 Check Float Type (1.3.2) - Problem
# Data Types
# Problem Statement:
#
# Create a variable salary with the value 85000.50 and check its data type.
# Code Needed:
#
# salary = 85000.50
#
# Hint:
#
# Use the type() function to check the data type of a variable.

# %%
salary = 85000.50

print(type(salary))
# Out:
# <class 'float'>

# %% [markdown]
# 🟨 Convert to Integer (1.3.3) - Problem
# Data Types
# Problem Statement:
#
# Convert the float of 120000.75, assigned to the variable salary_rate, to an integer; Print its type after conversion to verify it is an integer.
# Code Needed:
#
# salary_rate = 120000.75
#
# Hint:
#
# Use the int() function to convert a float to an integer.

# %%
salary_rate = 120000.75

salary_rate = int(salary_rate)

print(f"Salary rate: {salary_rate}\nVariable type: {type(salary_rate)}")
# Out:
# Salary rate: 120000
# Variable type: <class 'int'>

# %% [markdown]
# 🟥 Check String Type (1.3.4) - Problem
# Data Types
# Problem Statement:
#
# Check if the variable company_name is of the type str. company_name is set to 'DataWiz Inc.'.
# Code Needed:
#
# company_name = 'DataWiz Inc.'
#
# Hint:
#
# Use the isinstance() function to check if a variable is of a specific type. For the function isinstance(), pass in two arguments within the parenthesis of the function of company_name and then str.

# %%
company_name = 'DataWiz Inc.'

#print(type(company_name) == str)
print(isinstance(company_name,str))
# Out:
# True

# %% [markdown]
# 🟩 Convert to Uppercase (1.4.1) - Problem
# Strings
# Problem Statement:
#
# Convert the string job_title to uppercase. The variable is set to 'data scientist'.
# Code Needed:
#
# job_title = 'data scientist'
#
# Hint:
#
# Use the upper() method to convert a string to uppercase.

# %%
job_title = 'data scientist'

job_title.upper()
# Out:
# 'DATA SCIENTIST'

# %% [markdown]
# 🟩 Replace Substring (1.4.2) - Problem
# Strings
# Problem Statement:
#
# Replace the word 'Analyst' with 'Engineer' in the string job_title. The variable is set to 'Data Analyst'.
# Code Needed:
#
# job_title = 'Data Analyst'
#
# Hint:
#
# Use the replace() method to replace a substring within a string.

# %%
job_title = 'Data Analyst'

job_title.replace('Analyst','Engineer')
# Out:
# 'Data Engineer'

# %% [markdown]
# 🟨 Concatenate Strings (1.4.3) - Problem
# Strings
# Problem Statement:
#
# Concatenate the strings seniority_level and job_title with a space in between. The variables are set to 'Senior' and 'Data Analyst' respectively.
# Code Needed:
#
# seniority_level = 'Senior'
# job_title = 'Data Analyst'
#
# Hint:
#
# Use the + operator to concatenate strings and include a space between them.

# %%
seniority_level = 'Senior'
job_title = 'Data Analyst'

seniority_level + ' ' + job_title
# Out:
# 'Senior Data Analyst'

# %% [markdown]
# 🟨 Check String Length (1.4.4) - Problem
# Strings
# Problem Statement:
#
# Check the length of a string job_title. The variable is set to 'Data Scientist'.
# Code Needed:
#
# job_title = 'Data Scientist'
#
# Hint:
#
# Use the len() function to check the strings length.

# %%
job_title = 'Data Scientist'

len(job_title)
# Out:
# 14

# %% [markdown]
# 🟩 Convert to Lowercase (1.4.5) - Problem
# Strings
# Problem Statement:
#
# Convert the string job_title to lowercase. The variable is set to 'DATA ENGINEER'.
# Code Needed:
#
# job_title = 'DATA ENGINEER'
#
# Hint:
#
# Use the lower() method to convert a string to uppercase.

# %%
job_title = 'DATA ENGINEER'

job_title.lower()
# Out:
# 'data engineer'

# %% [markdown]
# 🟩 Concatenate Strings (1.5.1) - Problem
# String Formatting
# Problem Statement:
#
# Concatenate the string 'Job Title: ' with the variable job_title which is set to 'Data Scientist'.
# Code Needed:
#
# job_title = 'Data Scientist'
#
# Hint:
#
# Use the + operator to concatenate strings.

# %%
job_title = 'Data Scientist'

print('Job Title: ' +job_title)
# Out:
# Job Title: Data Scientist

# %% [markdown]
# 🟩 Format with f-strings (1.5.2) - Problem
# String Formatting
# Problem Statement:
#
# Format a string to include the variables position and company using f-strings. The variables are set to 'Data Scientist' and 'DataWiz Inc.' respectively. The final string should state: 'Data Scientist at DataWiz'.
# Code Needed:
#
# position = 'Data Scientist'
# company = 'DataWiz Inc.'
#
# Hint:
#
# Use an f-string to format the string with variables.

# %%
position = 'Data Scientist'
company = 'DataWiz Inc.'

print(f'{position} at {company}')
# Out:
# Data Scientist at DataWiz Inc.

# %% [markdown]
# 🟩 Format with str.format() (1.5.3) - Problem
# String Formatting
# Problem Statement:
#
# Use the str.format() method to format the string to include the variables role and skill. The variables are set to 'Data Analyst' and 'Python' respectively. The final string should state: 'Role: Data Analyst, Skill: Python'
# Code Needed:
#
# role = 'Data Analyst'
# skill = 'Python'
#
# Hint:
#
# Use the str.format() method to format the string with variables.

# %%
role = 'Data Analyst'
skill = 'Python'

'Role: {}, Skill: {}'.format(role, skill)
# Out:
# 'Role: Data Analyst, Skill: Python'

# %% [markdown]
# 🟨 Format with %-formatting (1.5.4) - Problem
# String Formatting
# Problem Statement:
#
# Use %-formatting to format the string to include the variables role and skill. The variables are set to 'Data Engineer' and 'SQL' respectively. The final string should state: 'Role: Data Engineer, Skill: SQL'
# Code Needed:
#
# role = 'Data Engineer'
# skill = 'SQL'
#
# Hint:
#
# Use %-formatting to format the string with variables.

# %%
role = 'Data Engineer'
skill = 'SQL'

'Role: %s, Skill: %s' %(role,skill)
# Out:
# 'Role: Data Engineer, Skill: SQL'

# %% [markdown]
# 🟩 Calculate Annual Salary (1.6.1) - Problem
# Operators Part 1
# Problem Statement:
#
# Calculate the total annual salary for a data scientist given the monthly salary. The variable monthly_salary is set to 8000.
# Code Needed:
#
# monthly_salary = 8000
#
# Hint:
#
# Use the multiplication operator * to calculate the annual salary.

# %%
monthly_salary = 8000


annual_salary = monthly_salary * 12
print(annual_salary)


#monthly_salary *= 12
#print(monthly_salary)
# Out:
# 96000

# %% [markdown]
# 🟩 Compare Salaries (1.6.2) - Problem
# Operators Part 1
# Problem Statement:
#
# Determine if the average salary of a data analyst is greater than that of a data scientist. The variables avg_salary_analyst and avg_salary_scientist are set to 70000 and 85000 respectively.
# Code Needed:
#
# avg_salary_analyst = 70000
# avg_salary_scientist = 85000
#
# Hint:
#
# Use the greater than operator > to compare the two salaries.

# %%
avg_salary_analyst = 70000
avg_salary_scientist = 85000

avg_salary_analyst > avg_salary_scientist
# Out:
# False

# %% [markdown]
# 🟨 Calculate Remainder (1.6.3) - Problem
# Operators Part 1
# Problem Statement:
#
# Calculate the remainder when the total number of job applications (variable total_applications is set to 123) is divided by the number of job openings (variable job_openings is set to 67).
# Code Needed:
#
# total_applications = 123
# job_openings = 67
#
# Hint:
#
# Use the modulus operator % to find the remainder.

# %%
total_applications = 123
job_openings = 67

total_applications % job_openings
# Out:
# 56

# %% [markdown]
# 🟨 Increment Job Postings (1.6.4) - Problem
# Operators Part 1
# Problem Statement:
#
# Increment (or increase) the variable job_postings by 5. The variable job_postings is intially set to 20.
# Code Needed:
#
# job_postings = 20
#
# Hint:
#
# Use the addition assignment operator += to increment the value.

# %%
job_postings = 20

job_postings += 5
job_postings
# Out:
# 25

# %% [markdown]
# 🟨 Calculate Average Salary (1.6.5) - Problem
# Operators Part 1
# Problem Statement:
#
# Calculate the average salary from the minimum and maximum salaries. The variables min_salary and max_salary are set to 50000 and 120000 respectively.
# Code Needed:
#
# min_salary = 50000
# max_salary = 120000
#
# Hint:
#
# Use the addition and division operators to calculate the average.

# %%
min_salary = 50000
max_salary = 120000

avg_salary = (min_salary + max_salary) / 2
avg_salary
# Out:
# 85000.0

# %% [markdown]
# 🟩 Determine Python Experience (1.7.1) - Problem
# Conditional Statements
# Problem Statement:
#
# Output someone's skill level based on the number of years someone has been using Python. Use the following criteria:
#
#     Less than 2 years is 'Beginner'
#     2 or more years is 'Intermediate'
#
# Set the variable python_experience to 3 and test this variable in the if statement.
# Code Needed:
#
# python_experience = 3
#
# Hint:
#
# Use if and else statements to check the conditions.

# %%
python_experience = 3

if python_experience < 2:
  print('Beginner')
else:
  print('Intermediate')
# Out:
# Intermediate

# %% [markdown]
# 🟨 Determine Job Skill Level (1.7.2) - Problem
# Conditional Statements
# Problem Statement:
#
# Output someone's skill level based on the number of data science tools they know. Use the following criteria:
#
#     0-1 tools is 'Beginner'
#     2-4 tools is 'Intermediate'
#     More than 4 tools is 'Advanced'
#
# The variable tools_known is set to 3 to test with the if statement.
# Code Needed:
#
# tools_known = 3
#
# Hint:
#
# Use if, elif, and else statements to check the conditions.

# %%
tools_known = 2

if tools_known <= 1:
  level='Beginner'
elif tools_known <= 4:
  level='Intermediate'
else:
  level='Advanced'
print(level)
# Out:
# Intermediate

# %% [markdown]
# 🟥 Determine Job Title (1.7.3) - Problem
# Conditional Statements
# Problem Statement:
#
# Determine the job_title based on years of job experience and years of SQL experience. The variable job_experience is set to 4 and sql_experience is set to 2. Use the following criteria:
#
#     Less than 2 years of job experience:
#         0 SQL experience → "Associate Analyst"
#         1+ years of SQL experience → "Junior Analyst"
#
#     2 to 5 years of job experience:
#         0 SQL experience → "Associate Analyst"
#         1 year of SQL experience → "Intermediate Analyst"
#         2+ years of SQL experience → "Senior Analyst"
#
#     More than 5 years of job experience:
#         0–2 years of SQL experience → "Data Analyst"
#         3+ years of SQL experience → "Lead Analyst"
#
# Code Needed:
#
# job_experience = 4
# sql_experience = 2
#
# Hint:
#
#     Use nested if statements to check multiple conditions step by step.
#     Instead of using and, check the first condition in the outer if, and then check the second condition inside it.
#     We'll cover and in the Operators pt 2 lesson in order to handle multiple conditions; so you can solve it without it here.

# %%
job_experience = 5
sql_experience = 1

if job_experience < 2:
  if sql_experience < 1:
    job_title = 'Associate Analyst'
  else:
    job_title = 'Junior Analyst'
elif job_experience < 6:
  if sql_experience < 1:
    job_title = 'Associate Analyst'
  elif sql_experience < 2:
     job_title = 'Junior Analyst'
  else:
    job_title = 'Senior Analyst'
else:
    if sql_experience < 3:
      job_title = 'Data Analyst'
    else:
      job_title = 'Lead Analyst'

print(job_title)
# Out:
# Junior Analyst

# %% [markdown]
# 🟩 Access Second Job Title (1.8.1) - Problem
# Lists
# Problem Statement:
#
# Access the second job title in the list of job titles for data science roles and print it. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use list indexing to access the second item in the list. Remember that indexing starts at 0.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

job_titles[1]
# Out:
# 'Data Analyst'

# %% [markdown]
# 🟩 Change Third Job Title (1.8.2) - Problem
# Lists
# Problem Statement:
#
# Change the third job title in the list of job titles for data science roles to 'AI Specialist' and print the updated list. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use list indexing to access the third item in the list and assign a new value to it.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

job_titles[2]='AI Specialist'

job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'AI Specialist']

# %% [markdown]
# 🟩 Slice Job Titles List (1.8.3) - Problem
# Lists
# Problem Statement:
#
# Slice the list of job titles for data science roles to get the first two job titles and print the result. The list is ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']
#
# Hint:
#
# Use list slicing to get a subset of the list. The syntax is list[start:end].

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']

job_titles[0:2]
# Out:
# ['Data Scientist', 'Data Analyst']

# %% [markdown]
# 🟨 Append Job Title (1.8.4) - Problem
# Lists
# Problem Statement:
#
# Add a new job title 'Data Engineer' to the end of the list of job titles for data science roles and print the updated list. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use the append() method to add a new item to the end of the list.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

job_titles.append('Data Engineer')

job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Data Engineer']

# %% [markdown]
# 🟨 Insert Job Title (1.8.5) - Problem
# Lists
# Problem Statement:
#
# Insert a new job title 'Business Analyst' at the second position in the list of job titles for data science roles and print the updated list. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use the insert() method to add a new item at a specific position in the list.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

##insert(self, index, object, /)
##      Insert object before index.

job_titles.insert(1,'Business Analyst')

job_titles
# Out:
# ['Data Scientist',
#  'Business Analyst',
#  'Data Analyst',
#  'Machine Learning Engineer']

# %% [markdown]
# 🟩 Access Job Postings (1.9.1) - Problem
# Dictionaries
# Problem Statement:
#
# Access the value of the number of job postings for the key 'Data Analyst' from the dictionary job_postings and print it. The dictonary job_postings is set to {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}.
# Code Needed:
#
# job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
#
# Hint:
#
# Use the key inside square brackets [] to access the value.

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

job_postings['Data Analyst']
# Out:
# 80

# %% [markdown]
# 🟩 Add Job Role (1.9.2) - Problem
# Dictionaries
# Problem Statement:
#
# Add a new job role under the key 'AI Specialist' with a value of 30 postings to the dictionary job_postings and print the updated dictionary. The dictionary job_postings is set to {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}.
# Code Needed:
#
# job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
#
# Hint:
#
# Use the assignment operator = to add a new key-value pair to the dictionary.

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

job_postings['AI Specialist'] = 30
job_postings
# Out:
# {'Data Scientist': 120,
#  'Data Analyst': 80,
#  'Machine Learning Engineer': 50,
#  'AI Specialist': 30}

# %% [markdown]
# 🟨 Remove Job Role (1.9.3) - Problem
# Dictionaries
# Problem Statement:
#
# Remove the job role 'Machine Learning Engineer' from the dictionary job_postings and print the updated dictionary. The dictonary job_postings is set to {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}.
# Code Needed:
#
# job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
#
# Hint:
#
# Use the pop() method to remove a key-value pair from the dictionary.

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

job_postings.pop('Machine Learning Engineer')
job_postings
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80}

# %% [markdown]
# 🟨 Merge Dictionaries (1.9.4) - Problem
# Dictionaries
# Problem Statement:
#
# Merge two dictionaries job_postings1 and job_postings2 containing job roles and their postings. With job_postings1 set to {'Data Scientist': 120, 'Data Analyst': 80} and job_postings2 to {'Machine Learning Engineer': 50, 'AI Specialist': 30}. Print the merged dictionary.
# Code Needed:
#
# job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
# job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}
#
# Hint:
#
# Use the update() method to merge two dictionaries.

# %%
job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}

job_postings1.update(job_postings2)
print(job_postings1)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
# Using the ** operator (Python 3.5+)
job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}

merged_job_postings = {**job_postings1, **job_postings2}
print(merged_job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
# Using copy() and update()
job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}

merged_job_postings_copy = job_postings1.copy()
merged_job_postings_copy.update(job_postings2)
print(merged_job_postings_copy)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %% [markdown]
# 🟥 Create Nested Dictionary (1.9.5) - Problem
# Dictionaries
# Problem Statement:
#
# Create a nested dictionary job_details where each key is a job role and the value is another dictionary containing 'postings' and 'average_salary'. The details for each are: 'Data Scientist' has 120 postings and an average salary of 120000; 'Data Analyst' has 80 postings and an average salary of 80000; Machine Learning Engineer has 50 postings and average salary of 110000. Print the nested dictionary.
# Hint:
#
# Use nested curly braces {} to create a nested dictionary.

# %%
job_details = {
    'Data Scientist': {
        'postings': 120,
        'average_salary': 120000
    },
    'Data Analyst': {
        'postings': 80,
        'average_salary': 80000
    },
    'Machine Learning Engineer': {
        'postings': 50,
        'average_salary': 110000
    }
}

print(job_details)
# Out:
# {'Data Scientist': {'postings': 120, 'average_salary': 120000}, 'Data Analyst': {'postings': 80, 'average_salary': 80000}, 'Machine Learning Engineer': {'postings': 50, 'average_salary': 110000}}

# %% [markdown]
# 🟩 Add Job Title to Set (1.10.1) - Problem
# Sets
# Problem Statement:
#
# Add a new job title 'AI Specialist' to the set of unique job titles and print the updated set. The initial set of unique_job_titles is {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}.
# Code Needed:
#
# unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}
#
# Hint:
#
# Use the add() method to add a new item to the set.

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}

unique_job_titles.add('AI Specialist')

unique_job_titles
# Out:
# {'AI Specialist',
#  'Data Analyst',
#  'Data Scientist',
#  'Machine Learning Engineer'}

# %% [markdown]
# 🟩 Remove Job Title from Set (1.10.2) - Problem
# Sets
# Problem Statement:
#
# Remove the job title 'Data Analyst' from the set of unique job titles and print the updated set. The initial set of unique_job_titles is {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}.
# Code Needed:
#
# unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}
#
# Hint:
#
# Use the remove() method to delete a specific item from the set.

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}

unique_job_titles.remove('Data Analyst')

unique_job_titles
# Out:
# {'Data Scientist', 'Machine Learning Engineer'}

# %% [markdown]
# 🟩 Create Unique Job Locations Set (1.10.3) - Problem
# Sets
# Problem Statement:
#
# Create a set of job locations named job_locations from a list of job locations for data science roles and print the set. The list is ['New York', 'San Francisco', 'New York', 'Austin', 'San Francisco'].
# Code Needed:
#
# job_locations = ['New York', 'San Francisco', 'New York', 'Austin', 'San Francisco']
#
# Hint:
#
# Use the set() function to create a set from the list.

# %%
job_locations = ['New York', 'San Francisco', 'New York', 'Austin', 'San Francisco']

print(set(job_locations))
# Out:
# {'New York', 'Austin', 'San Francisco'}

# %% [markdown]
# 🟨 Union of Job Skills Sets (1.10.4) - Problem
# Sets
# Problem Statement:
#
# Find the union of two sets of job skills and print the result. The first set is {'Python', 'SQL', 'Tableau'} and the second set is {'R', 'SQL', 'Machine Learning'}.
# Code Needed:
#
# skills_set1 = {'Python', 'SQL', 'Tableau'}
# skills_set2 = {'R', 'SQL', 'Machine Learning'}
#
# Hint:
#
# A union combines two sets and removes any duplicates, giving you all unique items from both sets. Python sets have a built-in method called union() to do this. The syntax is: set1.union(set2).

# %%
skills_set1 = {'Python', 'SQL', 'Tableau'}
skills_set2 = {'R', 'SQL', 'Machine Learning'}


skills_set1.union(skills_set2)
# Out:
# {'Machine Learning', 'Python', 'R', 'SQL', 'Tableau'}

# %% [markdown]
# 🟩 Access Job Role (1.11.1) - Problem
# Tuples
# Problem Statement:
#
# Access the second job role from the tuple job_roles and print it. The job_roles variable is set to ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer').
# Code Needed:
#
# job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
#
# Hint:
#
# Use the index inside square brackets [] to access the value.

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')

job_roles[1]
# Out:
# 'Data Analyst'

# %% [markdown]
# 🟨 Add Job Role to Tuple (1.11.2) - Problem
# Tuples
# Problem Statement:
#
# Create a new tuple extended_job_roles by adding the job role 'AI Specialist' to the existing tuple job_roles. Print the new tuple. The job_roles is set to job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer').
# Code Needed:
#
# job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
#
# Hint:
#
# Use the + operator to concatenate two tuples.

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
extended_job_roles = ('AI Specialist',)
extended_job_roles += job_roles

extended_job_roles
# Out:
# ('AI Specialist',
#  'Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer')

# %% [markdown]
# 🟨 Remove Job Role from Tuple (1.11.3) - Problem
# Tuples
# Problem Statement:
#
# Remove the job role 'Data Analyst' from the tuple job_roles by converting it to a list and then back to a tuple. Print the updated tuple. The tuple job_roles is set to ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer').
# Code Needed:
#
# job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
#
# Hint:
#
# Convert the tuple to a list, use the remove() method, and convert it back to a tuple.

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')

job_roles_list = list(job_roles)

job_roles_list.remove('Data Analyst')
job_roles = tuple(job_roles_list)
job_roles
# Out:
# ('Data Scientist', 'Machine Learning Engineer')

# %% [markdown]
# 🟨 Unpack Job Postings Tuple (1.11.4) - Problem
# Tuples
# Problem Statement:
#
# Unpack the tuple job_postings into three variables data_scientist_postings, data_analyst_postings, and ml_engineer_postings. Print each variable. The variable job_postings is set to (120, 80, 50).
# Code Needed:
#
# job_postings = (120, 80, 50)
#
# Hint:
#
# Use multiple assignments to unpack the tuple into variables.

# %%
job_postings = (120, 80, 50)

data_scientist_postings, data_analyst_postings, ml_engineer_postings =job_postings

print(f'Data scientist postings: {data_scientist_postings}\nData analyst postings: {data_analyst_postings}\nML engineer postings: {ml_engineer_postings}')
# Out:
# Data scientist postings: 120
# Data analyst postings: 80
# ML engineer postings: 50

# %% [markdown]
# 🟥 Extract Nested Value from Tuple (1.11.5) - Problem
# Tuples
# Problem Statement:
#
# Extract and print the number of postings for 'Machine Learning Engineer' from the nested tuple job_details. The job_details is set to (('Data Scientist', 120), ('Data Analyst', 80), ('Machine Learning Engineer', 50)).
# Code Needed:
#
# job_details = (('Data Scientist', 120), ('Data Analyst', 80), ('Machine Learning Engineer', 50))
#
# Hint:
#
# Use indexing to access the nested tuple and then the specific item within it.

# %%
job_details = (('Data Scientist', 120), ('Data Analyst', 80), ('Machine Learning Engineer', 50))

job_details[2][1]
# Out:
# 50

# %% [markdown]
# 🟩 Check Object Identity (1.12.1) - Problem
# Operators Part 2
# Problem Statement:
#
# Check if the job_title1 of 'Data Engineer' is not the same object as the job_title2 of 'Data Scientist' and print the result.
# Code Needed:
#
# job_title1 = 'Data Engineer'
# job_title2 = 'Data Scientist'
#
# Hint:
#
# Use the is not operator to check if two variables are not the same object.

# %%
job_title1 = 'Data Engineer'
job_title2 = 'Data Scientist'

job_title1 is not job_title2
# Out:
# True

# %% [markdown]
# 🟩 Check Membership in List (1.12.2) - Problem
# Operators Part 2
# Problem Statement:
#
# Determine if the job location 'New York' is in the list of job_locations ['New York', 'San Francisco', 'Austin'] and print the result.
# Code Needed:
#
# job_locations = ['New York', 'San Francisco', 'Austin']
#
# Hint:
#
# Use the in operator to check if an item exists in a list.

# %%
job_locations = ['New York', 'San Francisco', 'Austin']

'New York' in job_locations
# Out:
# True

# %% [markdown]
# 🟨 Check Substring Not in String (1.12.3) - Problem
# Operators Part 2
# Problem Statement:
#
# Check if the job_title 'Data Analyst' is not in the job_description string 'Data Scientist at Tech Corp' and print the result.
# Code Needed:
#
# job_title = 'Data Analyst'
# job_description = 'Data Scientist at Tech Corp'
#
# Hint:
#
# Use the not in operator to check if a substring does not exist in a string.

# %%
job_title = 'Data Analyst'
job_description = 'Data Scientist at Tech Corp'

job_title not in job_description
# Out:
# True

# %% [markdown]
# 🟨 Check Multiple Memberships (1.12.4) - Problem
# Operators Part 2
# Problem Statement:
#
# Check if both 'Data Scientist' and 'Machine Learning Engineer' are in the list of job titles ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'] and print the result.
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use the and operator to combine two membership checks.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

'Data Scientist' in job_titles and 'Machine Learning Engineer' in job_titles
# Out:
# True

# %% [markdown]
# 🟥 Bitwise OR Operation (1.12.5) - Problem
# Operators Part 2
# Problem Statement:
#
# Perform a bitwise OR operation on the binary representations of the salaries 100000 and 50000 and print the result. Named salary1 and salary2 respectively.
# Code Needed:
#
# salary1 = 100000
# salary2 = 50000
#
# Hint:
#
# Use the | operator to perform a bitwise OR operation.

# %%
salary1 = 100000
salary2 = 50000

print(salary1 | salary2)
# Out:
# 116720

# %% [markdown]
# 🟩 Print Job Titles (1.13.1) - Problem
# Loops
# Problem Statement:
#
# Print the job titles from the list job_titles using a for loop. The list job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use a for loop to iterate over the list and print each item.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

for job in job_titles:
  print(job)
# Out:
# Data Scientist
# Data Analyst
# Machine Learning Engineer

# %% [markdown]
# 🟨 Total Job Postings (1.13.2) - Problem
# Loops
# Problem Statement:
#
# Calculate the total number of job postings from a list using a while loop. The list of job postings is [5, 10, 15, 20, 25].
# Code Needed:
#
# job_postings = [5, 10, 15, 20, 25]
#
# Hint:
#
# Use a while loop to iterate through the list and sum the values. Use a variable index, set to 0, to iteratively go through the index of the list inside the while loop.

# %%
index = 0
job_number = 0
job_postings = [5, 10, 15, 20, 25]
while index < len(job_postings):
  job_number += job_postings[index]
  index+=1
print (job_number)
# Out:
# 75

# %% [markdown]
# 🟨 Print Job Titles with Index (1.13.3) - Problem
# Loops
# Problem Statement:
#
# Print the job titles from the list job_titles along with their index using a for loop and the enumerate() function. The list job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
#
# Hint:
#
# Use the enumerate() function to get both the index and the item in the list.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

for index, job in enumerate(job_titles):
  print(f'{index} {job}')
# Out:
# 0 Data Scientist
# 1 Data Analyst
# 2 Machine Learning Engineer

# %% [markdown]
# 🟨 Find First Engineer (1.13.4) - Problem
# Loops
# Problem Statement:
#
# Use a while loop to find the first job title that contains the word 'Engineer'. The list of job titles is ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Software Engineer'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Software Engineer']
#
# Hint:
#
# Use a while loop to iterate through the list and check if 'Engineer' is in each job title. Once you find the first matching job title, you'll want to stop the loop from continuing. Python has a special command called break that exits a loop immediately when you no longer need to continue searching.

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Software Engineer']
index = 0
while index < len(job_titles):
  if 'Engineer' in job_titles[index]:
    print(job_titles[index])
    break
  index += 1
# Out:
# Machine Learning Engineer

# %% [markdown]
# 🟥 Print Job Titles Containing 'Data' (1.13.5) - Problem
# Loops
# Problem Statement:
#
# You have the following dictionary of positions_skills which is set to {'Data Scientist': ['Python', 'R'], 'Data Analyst': ['SQL', 'Excel'], 'Machine Learning Engineer': ['Python', 'TensorFlow']}. The keys are a data science position, and the values are a list of skills required for the position. Print a message for each individual skill required for these data science positions (e.g., "The role of Data Scientist requires proficiency in Python").
# Code Needed:
#
# positions_skills = {
#     'Data Scientist': ['Python', 'R'],
#     'Data Analyst': ['SQL', 'Excel'],
#     'Machine Learning Engineer': ['Python', 'TensorFlow']
# }
#
# Hint:
#
# Use a nested for loop to iterate over each job title and its corresponding skills list.

# %%
positions_skills = {
    'Data Scientist': ['Python', 'R'],
    'Data Analyst': ['SQL', 'Excel'],
    'Machine Learning Engineer': ['Python', 'TensorFlow']
}
'''
# One sentence only
for position in positions_skills:
  skills = ', '.join(positions_skills.get(position))
  print(f'The role of {position} requires proficiency in {skills}')
'''
for position, skills in positions_skills.items():
    for skill in skills:
        print(f'The role of {position}, requires proficiency in {skill}.')
# Out:
# The role of Data Scientist, requires proficiency in Python.
# The role of Data Scientist, requires proficiency in R.
# The role of Data Analyst, requires proficiency in SQL.
# The role of Data Analyst, requires proficiency in Excel.
# The role of Machine Learning Engineer, requires proficiency in Python.
# The role of Machine Learning Engineer, requires proficiency in TensorFlow.

# %% [markdown]
# 🟩 Convert Salaries to EUR (1.14.1) - Problem
# List Comprehensions
# Problem Statement:
#
# Create a list comprehension that converts a list of salaries from USD to EUR using a conversion rate of 0.85. With the list of salaries being: salaries_usd = [100000, 120000, 80000, 90000].
# Code Needed:
#
# salaries_usd = [100000, 120000, 80000, 90000]
#
# Hint:
#
# Multiply each salary by 0.85 within the list comprehension.

# %%
salaries_usd = [100000, 120000, 80000, 90000]

salaries_eur=[salary*0.85 for salary in salaries_usd]

salaries_eur
# Out:
# [85000.0, 102000.0, 68000.0, 76500.0]

# %% [markdown]
# 🟨 Create List of Data Jobs (1.14.2) - Problem
# List Comprehensions
# Problem Statement:
#
# Create a list of data science job titles that require more than 2 years of experience from the given dictionary. With job_experience set to {'Data Scientist': 3, 'Data Analyst': 1, 'Machine Learning Specialist': 4, 'Data Engineer': 2}.
# Code Needed:
#
# job_experience = {'Data Scientist': 3, 'Data Analyst': 1, 'Machine Learning Specialist': 4, 'Data Engineer': 2}
#
# Hint:
#
# Use a list comprehension to filter job titles based on experience requirements.

# %%
job_experience = {'Data Scientist': 3, 'Data Analyst': 1, 'Machine Learning Specialist': 4, 'Data Engineer': 2}

job_req = [job for job in job_experience if job_experience.get(job) > 2]

job_req
# Out:
# ['Data Scientist', 'Machine Learning Specialist']

# %% [markdown]
# 🟥 Extract High Salary Jobs (1.14.3) - Problem
# List Comprehensions
# Problem Statement:
#
# Create a list comprehension that extracts job titles with salaries greater than 90,000 from a given list of dictionaries containing job titles and salaries. The dictionary is job_salary_dicts named and it is set to [{'job_title': 'Data Scientist', 'salary': 100000}, {'job_title': 'Data Analyst', 'salary': 120000}, {'job_title': 'Data Engineer', 'salary': 80000}, {'job_title': 'Machine Learning Engineer', 'salary': 90000}].
# Code Needed:
#
# job_salary_dicts = [
#     {'job_title': 'Data Scientist', 'salary': 100000},
#     {'job_title': 'Data Analyst', 'salary': 120000},
#     {'job_title': 'Data Engineer', 'salary': 80000},
#     {'job_title': 'Machine Learning Engineer', 'salary': 90000}
# ]
#
# Hint:
#
# Use an if condition within the list comprehension to filter out dictionaries with salaries less than or equal to 90,000.

# %%
job_salary_dicts = [
{'job_title': 'Data Scientist', 'salary': 100000}, {'job_title': 'Data Analyst', 'salary': 120000}, {'job_title': 'Data Engineer', 'salary': 80000}, {'job_title': 'Machine Learning Engineer', 'salary': 90000} ]

job_filter = [job['job_title'] for job in job_salary_dicts if job['salary']> 90_000]

job_filter
# Out:
# ['Data Scientist', 'Data Analyst']

# %% [markdown]
# 🟩 Job Title Contains (1.16.1) - Problem
# Functions
# Problem Statement:
#
# Create a function job_title_contains that takes a job title and a keyword as arguments, and returns True if the job title contains the keyword, otherwise returns False.
#
# To confirm the function works, set the job_title to 'Data Scientist' and the keyword to 'Data'.
# Code Needed:
#
# job_title = 'Data Scientist'
# keyword = 'Data'
#
# Hint:
#
# Use the in operator to check if the keyword is in the job title.

# %%
job_title = 'Data Scientist'
keyword = 'Data'

def check(job_title, keyword):
    return keyword in job_title

check(job_title, keyword)
# Out:
# True

# %% [markdown]
# 🟩 Average Salary (1.16.2) - Problem
# Functions
# Problem Statement:
#
# Create a function average_salary that takes a list of salaries and returns the average salary. With the salaries set as [95000, 120000, 105000, 90000, 130000].
# Code Needed:
#
# salaries = [95000, 120000, 105000, 90000, 130000]
#
# Hint:
#
# Use the sum() function to get the total salary and the len() function to get the number of salaries.

# %%
def average_salary(salaries):
    return sum(salaries) / len(salaries)

salaries = [95000, 120000, 105000, 90000, 130000]
average_salary(salaries)
# Out:
# 108000.0

# %% [markdown]
# 🟨 Salary Statistics (1.16.3) - Problem
# Functions
# Problem Statement:
#
# Create a function salary_statistics that takes a list of salaries and returns a dictionary with the minimum, maximum, and average salary. The list of salaries is set to [95000, 120000, 105000, 90000, 130000].
# Code Needed:
#
# salaries = [95000, 120000, 105000, 90000, 130000]
#
# Hint:
#
# Use the min(), max(), sum(), and len() functions to calculate the statistics.

# %%
salaries = [95000, 120000, 105000, 90000, 130000]

def salary_statistics(salary):
  return {'Minimum salary': min(salary),
          'Maximum salary': max(salary),
          'Average Salary': int(sum(salary)/len(salary))
          }

salary_statistics(salaries)
# Out:
# {'Minimum salary': 90000, 'Maximum salary': 130000, 'Average Salary': 108000}

# %% [markdown]
# 🟥 Job Posting Summary (1.16.4) - Problem
# Functions
# Problem Statement:
#
# Create a function job_posting_summary that takes a list of job postings, where each posting is a dictionary with keys 'title', 'location', and 'salary', and returns a summary dictionary with the total number of postings, the average salary, and a list of unique locations. The job_postings is set to [{'title': 'Data Scientist', 'location': 'New York', 'salary': 95000}, {'title': 'Data Analyst', 'location': 'San Francisco', 'salary': 85000}, {'title': 'Machine Learning Engineer', 'location': 'New York', 'salary': 115000}].
# Code Needed:
#
# job_postings = [
#     {'title': 'Data Scientist', 'location': 'New York', 'salary': 95000},
#     {'title': 'Data Analyst', 'location': 'San Francisco', 'salary': 85000},
#     {'title': 'Machine Learning Engineer', 'location': 'New York', 'salary': 115000}
# ]
#
# Hint:
#
# Use a set to store unique locations and the sum() function to calculate the total salary.

# %%
job_postings = [ {'title': 'Data Scientist', 'location': 'New York', 'salary': 95000}, {'title': 'Data Analyst', 'location': 'San Francisco', 'salary': 85000}, {'title': 'Machine Learning Engineer', 'location': 'New York', 'salary': 115000} ]
'''
def job_postings_summary(job_postings):
  number_of_postings=len(job_postings)

  list_of_salaries=[job['salary'] for job in job_postings]
  avg_salary= round(sum(list_of_salaries)/len(list_of_salaries),2)

  unique_locations={job['location'] for job in job_postings}
  unique_locations=list(unique_locations)

  return {'Number of postings': number_of_postings,
          'Average salary': avg_salary,
          'Locations': unique_locations}

job_postings_summary(job_postings)
'''
def job_posting_summary(job_postings):
    total_postings = len(job_postings)
    total_salary = sum(posting['salary'] for posting in job_postings)
    average_salary = total_salary / total_postings
    unique_locations = list(set(posting['location'] for posting in job_postings))
    return {
        'total_postings': total_postings,
        'average_salary': average_salary,
        'unique_locations': unique_locations
    }

job_postings = [
    {'title': 'Data Scientist', 'location': 'New York', 'salary': 95000},
    {'title': 'Data Analyst', 'location': 'San Francisco', 'salary': 85000},
    {'title': 'Machine Learning Engineer', 'location': 'New York', 'salary': 115000}
]
job_posting_summary(job_postings)
# Out:
# {'total_postings': 3,
#  'average_salary': 98333.33333333333,
#  'unique_locations': ['San Francisco', 'New York']}

# %% [markdown]
# 🟩 Calculate Average Salary (1.17.1) - Problem
# Lambda
# Problem Statement:
#
# Create a lambda function to calculate the average salary from a list of salaries. With salaries set as [95000, 120000, 105000, 90000, 130000].
# Code Needed:
#
# salaries = [95000, 120000, 105000, 90000, 130000]
#
# Hint:
#
# Use the sum and len functions within the lambda function to calculate the average.

# %%
salaries = [95000, 120000, 105000, 90000, 130000]

average_salary=(lambda x: sum(x)/len(x))(salaries)

average_salary
# Out:
# 108000.0

# %% [markdown]
# 🟨 Filter Job Titles (1.17.2) - Problem
# Lambda
# Problem Statement:
#
# Create a lambda function to check if a job title contains the word 'Data' and use it to filter a list of job titles. With job_titles set to ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst'].
# Code Needed:
#
# job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']
#
# Hint:
#
# Use the in operator within the lambda function to check for the presence of the word 'Data'. Use the filter function to filter this data out.

# %%
job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']
job_filter = list(filter(lambda job: "Data" in job, job_titles))
job_filter
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %% [markdown]
# 🟥 Filter Remote Python Jobs (1.17.3) - Problem
# Lambda
# Problem Statement:
#
# Create a lambda function to filter remote job postings that require Python skills from a list of job postings. The list for the variable job_postings is shown below.
# Code Needed:
#
# job_postings = [
#     {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#     {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
#     {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
#     {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True}
# ]
#
# Hint:
#
# Use the filter function in combination with a lambda function that checks both conditions.

# %%
job_postings = [ {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True}, {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False}, {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True}, {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True} ]

filter_jobs=list(filter(lambda job: job['remote'] and 'Python' in job['skills'], job_postings))
filter_jobs
# Out:
# [{'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#  {'title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow'],
#   'remote': True}]

# %% [markdown]
# 🟩 Calculate Annual Salary (1.18.1) - Problem
# Modules
# Problem Statement:
#
# Create a module named salary_calculator with a function calculate_annual_salary that takes an hourly wage and hours per week, and returns the annual salary. Import this module and use the function to calculate the annual salary for an hourly wage of $50 and 40 hours per week.
# Code Needed:
#
# To save your module in Google Collab use this line in the module code.
#
# %%writefile salary_calculator.py
#
# Hint:
#
# Use the import statement to import the module and call the function with the required arguments.

# %%
# %%writefile salary_calculator.py
def calculate_annual_salary(hourly_wage, hours_per_week):
  return hourly_wage*hours_per_week*52
# Out:
# Overwriting salary_calculator.py

# %%
from salary_calculator import calculate_annual_salary
calculate_annual_salary(50,40)
# Out:
# 104000

# %% [markdown]
# 🟨 Filter Job Postings by Location (1.18.2) - Problem
# Modules
# Problem Statement:
#
# Create a module named job_filter with a function filter_by_location that takes a list of job postings and a location and returns a list of job postings in that location. Import this module and use the function to filter job postings in 'New York'. Use the variable of job_postings shown below.
# Code Needed:
#
# To save your module in Google Collab use this in one cell in your notebook.
#
# %%writefile job_filter.py
# # run this in another cell to initiate the job_postings variable
#
# job_postings = [
#     {'title': 'Data Scientist', 'location': 'New York'},
#     {'title': 'Data Analyst', 'location': 'San Francisco'},
#     {'title': 'Machine Learning Engineer', 'location': 'New York'}
# ]
#
# Hint:
#
# Use the import statement to import the module and call the function with the required arguments.

# %%
# %%writefile job_filter.py
def filter_by_location(jobs, city):
  city_filter= list(filter(lambda job: job['location']==city, jobs))
  list_of_jobs=[job['title'] for job in city_filter]
  return list_of_jobs
# Out:
# Overwriting job_filter.py

# %%
from job_filter import filter_by_location

job_postings = [ {'title': 'Data Scientist', 'location': 'New York'}, {'title': 'Data Analyst', 'location': 'San Francisco'}, {'title': 'Machine Learning Engineer', 'location': 'New York'} ]

filter_by_location(job_postings, 'New York')
# Out:
# ['Data Scientist', 'Machine Learning Engineer']

# %% [markdown]
# 🟩 List Installed Packages (1.20.1) - Problem
# Library
# Problem Statement:
#
# List all installed packages in your current Google Colab environment using pip.
# Hint:
#
# Use the !pip list command to list all installed packages.

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------------
# absl-py                                  1.4.0
# absolufy-imports                         0.3.1
# accelerate                               1.11.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.2
# aiosignal                                1.4.0
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.17.1
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.11.0
# ...

# %% [markdown]
# 🟨 Install and Verify Library (1.20.2) - Problem
# Library
# Problem Statement:
#
# Install a third-party library named pyjokes using pip.
#
# Verify its installation by importing it in and then running the method get_jokes().
# Hint:
#
# Use the !pip install command to install the library.
#
# Use . notation to access the method get_jokes() of pyjokes.

# %%
# !pip install pyjokes
import pyjokes
pyjokes.get_jokes()

# %% [markdown]
# 🟨 List Files in Directory (1.20.3) - Problem
# Library
# Problem Statement:
#
# Use the os library to list all files in the current directory and print their names with the function os.listdir('.').
# Hint:
#
# Use the os.listdir function to get the list of files in the current directory, which is denoted by: '.'

# %%
import os

#os.listdir('.')

files = os.listdir('.')
for file in files:
    print(file)
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# 🟥 Fetch Data from URL (1.20.4) - Problem
# Library
# Problem Statement:
#
# Use the requests library to fetch data from the URL 'https://pokeapi.co/api/v2/pokemon/pikachu' and print the JSON response.
# Code Needed:
#
# url = 'https://pokeapi.co/api/v2/pokemon/pikachu'
#
# Hint:
#
# Use the requests.get() function to fetch data from the URL, providing url as the argument; this will provide a response object.
# With the response object, use the json method to get the response formatted as json.

# %%
import requests as rq

rq.get('https://pokeapi.co/api/v2/pokemon/pikachu').json()

# %% [markdown]
# 🟩 Create JobPosting Class (1.21.1) - Problem
# Classes
# Problem Statement:
#
#     Create a class named JobPosting with attributes title, company, and location.
#     Create an instance of an object (called job) of this class with the title 'Data Scientist', company 'Tech Innovations', and location 'New York'.
#     Print the attributes of the object.
#
# Code Needed:
#
# job = JobPosting('Data Scientist', 'Tech Innovations', 'New York')
#
# Hint:
#
# Use the __init__ method to initialize the attributes of the class.

# %%
class JobPosting():

  def __init__(self, title, company, location):
    self.title = title
    self.company = company
    self.location = location
  def __repr__(self):
    return f'{self.title}, {self.company}, {self.location}'

job = JobPosting('Data Scientist', 'Tech Innovations', 'New York')
job
# Out:
# Data Scientist, Tech Innovations, New York

# %%
class JobPosting():

  def __init__(self, title, company, location, salary):
    self.title = title
    self.company = company
    self.location = location
    self.salary = salary
  def __repr__(self):
    return f'{self.title}, {self.company}, {self.location}, {self.salary:,.2f}'
  def to_dict(self):
    return self.__dict__
    '''
    dictionary={}
    dictionary['title']=self.title
    dictionary['company']=self.company
    dictionary['location']=self.location
    dictionary['salary']=self.salary
    return dictionary
'''
job = JobPosting('Data Scientist', 'Tech Innovations', 'New York', 120000)

job.to_dict()
# Out:
# {'title': 'Data Scientist',
#  'company': 'Tech Innovations',
#  'location': 'New York',
#  'salary': 120000}

# %% [markdown]
# 🟥 Compare Job Salaries (1.21.3) - Problem
# Classes
# Problem Statement:
#
#     Create a class named JobPosting with a method compare_salary that compares the salary of two job postings and returns the title of the job with the higher salary.
#     Instantiate two objects called job1 and job2 of this class and compare their salaries using the compare_salary method.
#     The two objects are defined below in the code needed.
#
# Code Needed:
#
# job1 = JobPosting('Data Scientist', 'Tech Innovations', 'New York', 120000)
# job2 = JobPosting('Data Analyst', 'Data Driven Co', 'San Francisco', 100000)
#
# Hint:
#
# Use a method to compare the salary attribute of two objects and return the title of the job with the higher salary.

# %%
class JobPosting():

  def __init__(self, title, company, location, salary):
    self.title = title
    self.company = company
    self.location = location
    self.salary = salary
  def __repr__(self):
    return f'{self.title}, {self.company}, {self.location}, {self.salary:,.2f}'
  def compare_salary(self, other_job):
    if self.salary > other_job.salary:
      return self.title
    else:
      return other_job.title





job1 = JobPosting('Data Scientist', 'Tech Innovations', 'New York', 120000)
job2 = JobPosting('Data Analyst', 'Data Driven Co', 'San Francisco', 100000)

job1.compare_salary(job2)
# Out:
# 'Data Scientist'

# %% [markdown]
# 🟩 Create NumPy Array (1.22.1) - Problem
# 1️⃣ Basics - NumPy 🔢
# Problem Statement:
#
# Create a NumPy array representing the number of job applications received each day for a week (7 days). The array should be called applications and contain the following numbers: [10, 15, 7, 20, 25, 30, 5]. Print the array.
# Code Needed:
#
# applications_list = [10, 15, 7, 20, 25, 30, 5]
#
# Hint:
#
# Use the np.array function to create the array.

# %%
import numpy as np

applications_list = [10, 15, 7, 20, 25, 30, 5]
applications= np.array(applications_list)
applications
# Out:
# array([10, 15,  7, 20, 25, 30,  5])

# %% [markdown]
# 🟩 Slicing Array (1.22.2) - Problem
#
# 1️⃣ Basics - NumPy 🔢
# Problem Statement:
#
# Create a NumPy array representing the number of job postings for different job titles called postings. The array contains [10, 15, 7, 20, 25, 30, 5]. Use slicing to get the number of postings for the first three job titles.
# Code Needed:
#
# postings_list = [10, 15, 7, 20, 25, 30, 5]
#
# Hint:
#
# Use slicing to get the first three elements of the array.

# %%
postings_list = [10, 15, 7, 20, 25, 30, 5]
postings=np.array(postings_list)
postings[0:3]
# Out:
# array([10, 15,  7])

# %% [markdown]
# 🟨 Highest and Lowest Salary (1.22.3) - Problem
# 1️⃣ Basics - NumPy 🔢
# Problem Statement:
#
# Create a NumPy array representing the salaries called salaries offered for five different job positions. Calculate the highest and lowest salary using NumPy functions. The array salaries contains [70000, 85000, 60000, 95000, 80000].
# Code Needed:
#
# salaries_list = [70000, 85000, 60000, 95000, 80000]
#
# Hint:
#
# Use the np.max and np.min functions to find the highest and lowest salaries.

# %%
salaries_list = [70000, 85000, 60000, 95000, 80000]

salaries_offered = np.array(salaries_list)
print(f'Maximum salary: {np.max(salaries_offered)}\nMinimum salary: {np.min(salaries_offered)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-457732631.py in <cell line: 0>()
#       1 salaries_list = [70000, 85000, 60000, 95000, 80000]
#       2
# ----> 3 salaries_offered = np.array(salaries_list)
#       4 print(f'Maximum salary: {np.max(salaries_offered)}\nMinimum salary: {np.min(salaries_offered)}')
#
# NameError: name 'np' is not defined

# %%
# !pip install datasets
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# 🟩 Load and Display Last 5 Rows (1.23.1) - Problem
# Pandas Intro
# Problem Statement:
#
#     Import the Pandas library under the alias pd.
#     Import the load_dataset function from datasets library.
#     Load the course dataset ('lukebarousse/data_jobs') using the load_dataset function.
#     Transform it into a DataFrame and display the last 5 rows.
#
# Hint:
#
# Use the tail method to display the last 5 rows.

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df.tail(5)
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %% [markdown]
# 🟩 Select Job Location Column (1.23.2) - Problem
# Pandas Intro
# Problem Statement:
#
# Select and display the job_location column from the course dataset DataFrame you created in the last exercise using bracket notation.
# Code Needed:
#
# import pandas as pd
# from datasets import load_dataset
#
# dataset = load_dataset('lukebarousse/data_jobs')
# df = dataset['train'].to_pandas()
#
# Hint:
#
# Use the bracket notation to select the column.

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_location']
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 785736                              Singapura
# 785737                     Bad Rodach, Jerman
# 785738                               Malaysia
# 785739    Newark, New Jersey, Amerika Serikat
# 785740                                  India
# Name: job_location, Length: 785741, dtype: object

# %% [markdown]
# 🟩 Select Search Location Column (1.23.3) - Problem
# Pandas Intro
# Problem Statement:
#
# Select and display the search_location column from the DataFrame using dot notation.
# Code Needed:
#
# import pandas as pd
# from datasets import load_dataset
#
# dataset = load_dataset('lukebarousse/data_jobs')
# df = dataset['train'].to_pandas()
#
# Hint:
#
# Use the dot notation to select the column.

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df.search_location
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# 🟩 Select Job Title from 57th Row Element (1.23.4) - Problem
# Pandas Intro
# Problem Statement:
#
# Select the job_title from the 57th row from the DataFrame using its index.
# Code Needed:
#
# import pandas as pd
# from datasets import load_dataset
#
# dataset = load_dataset('lukebarousse/data_jobs')
# df = dataset['train'].to_pandas()
#
# Hint:
#
# Use the column title and index to select the specific element.

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df.job_title[56]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]
# 'Principal Statistical Scientist'

# %% [markdown]
# 🟩 Access Third Row (1.24.4) - Problem
# Pandas Inspection
# Problem Statement:
#
# Access the third row of the DataFrame using its index and display it.
# Hint:
#
# Use the iloc method to access the row by its index.

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# ...

# %% [markdown]
# 🟨 Unique Job Countries (1.24.2) - Problem
# Pandas Inspection
# Problem Statement:
#
# Display the unique values in the job_country column.
# Hint:
#
# Use the unique method to get the unique values of the job_country column.

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %% [markdown]
# 🟨 Filter by Job Schedule Type and Display (1.24.3) - Problem
# Pandas Inspection
# Problem Statement:
#
# Display the first 3 rows of the DataFrame where the job_schedule_type is 'Full-time'.
# Hint:
#
# Use boolean indexing to filter the DataFrame based on the job_schedule_type column and then use the head method to display the first 3 rows.

# %%
#df[df.job_schedule_type == 'Full-time'].iloc[:3]
df[df.job_schedule_type == 'Full-time'].head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %% [markdown]
# 🟥 Check Missing Values (1.24.4) - Problem
# Pandas Inspection
# Problem Statement:
#
# Check for missing values in the job_skills column and display the rows where the values are not NA.
# Hint:
#
# Use the notna method to check for not NA values and boolean indexing to filter the DataFrame.

# %%
df[df.job_skills.notna()]
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %% [markdown]
# 🟩 Sort by Salary (1.25.1) - Problem
# Pandas Cleaning
# Problem Statement:
#
# Sort the DataFrame by salary_year_avg in descending order and display the first 10 rows.
# Hint:
#
# Use the sort_values method to sort the DataFrame by salary_year_avg in descending order.

# %%
df.sort_values(by='salary_year_avg', ascending=False).head(10)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
# 404932          Data Engineer
# 554140         Data Scientist
# 417241  Senior Data Scientist
# 618461  Senior Data Scientist
# 124265         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
# 404932               Hybrid - Data Engineer - Up to $600k
# 554140          Staff Data Scientist - Business Analytics
# 417241                              Senior Data Scientist
# 618461                         VP Data Science & Research
# ...

# %% [markdown]
# 🟩 Create Remote Column (1.25.2) - Problem
# Pandas Cleaning
# Problem Statement:
#
# Create a new column is_remote that indicates whether the job is remote (True) or not (False) based on the job_work_from_home column.
# Hint:
#
# Use boolean indexing to create the new column based on the job_work_from_home colum
# *testo in corsivo*

# %%
df['is_remote'] = df['job_work_from_home']
df[['job_work_from_home','is_remote']]
# Out:
#         job_work_from_home  is_remote
# 554784               False      False
# 665811               False      False
# 168402                True       True
# 387378               False      False
# 160521                True       True
# ...                    ...        ...
# 785736               False      False
# 785737               False      False
# 785738               False      False
# 785739               False      False
# 785740               False      False
#
# [785741 rows x 2 columns]

# %% [markdown]
# 🟩 Extract Year from Date (1.25.3) - Problem
# Pandas Cleaning
# Problem Statement:
#
# Create a new column job_posted_year that extracts the year from the job_posted_date column and display the first 5 rows.
# Hint:
#
# Use the dt accessor to extract the year from the job_posted_date column.

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_posted_year']= df['job_posted_date'].dt.year
df.head(5)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
#
#                   job_location                        job_via  \
# 554784             Madison, SD  via Cooperative Career Center
# 665811  Pretoria, South Africa                     via Adzuna
# 168402                Anywhere               via Y Combinator
# 387378            New York, NY               via ZipRecruiter
# 160521                Anywhere                   via LinkedIn
#
# ...

# %% [markdown]
# 🟨 Drop Missing Salaries (1.25.4) - Problem
# Pandas Cleaning
# Problem Statement:
#
# Drop rows where the salary_year_avg column has missing values and display the first 5 rows of the cleaned DataFrame.
# Hint:
#
# Use the dropna method to remove rows with missing values in the salary_year_avg column.

# %%
df.dropna(subset=['salary_year_avg'],inplace=True)
df.head(5)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
#
#                   job_location                        job_via  \
# 554784             Madison, SD  via Cooperative Career Center
# 665811  Pretoria, South Africa                     via Adzuna
# 168402                Anywhere               via Y Combinator
# 387378            New York, NY               via ZipRecruiter
# 160521                Anywhere                   via LinkedIn
#
# ...

# %% [markdown]
# 🟩 Calculate Mean Salary (1.26.1) - Problem
# Pandas Analysis
# Problem Statement:
#
# Calculate the mean of the salary_year_avg column and display the result.
# Hint:
#
# Use the mean method to calculate the mean of the salary_year_avg column.

# %%
print(f'{df['salary_year_avg'].mean():.2f}')
# Out:
# 123286.27

# %% [markdown]
# 🟩 Calculate Median Salary (1.26.2) - Problem
# Pandas Analysis
# Problem Statement:
#
# Calculate the median of the salary_year_avg column and display the result.
# Hint:
#
# Use the median method to calculate the median of the salary_year_avg column.

# %%
print(int(df['salary_year_avg'].median()))
# Out:
# 115000

# %% [markdown]
# 🟨 Average Hourly Salary by Job Title (1.26.3) - Problem
# Pandas Analysis
# Problem Statement:
#
# Group the DataFrame by job_title_short and calculate the average salary_hour_avg for each job title. Display the result.
# Hint:
#
# Use the groupby method to group the DataFrame by job_title_short and then use the mean method to calculate the average salary_hour_avg for each group.

# %%
df.groupby('job_title_short')['salary_hour_avg'].mean().round(2)
# Out:
# job_title_short
# Business Analyst             42.72
# Cloud Engineer               45.56
# Data Analyst                 38.11
# Data Engineer                57.20
# Data Scientist               49.36
# Machine Learning Engineer    48.48
# Senior Data Analyst          47.66
# Senior Data Engineer         62.85
# Senior Data Scientist        54.11
# Software Engineer            46.45
# Name: salary_hour_avg, dtype: float64

# %% [markdown]
# 🟨 Job with Lowest Hourly Salary (1.26.4) - Problem
# Pandas Analysis
# Problem Statement:
#
# Find the job title with the lowest average hourly salary and display the job title and the salary.
# Hint:
#
# Use the idxmin method to find the index of the minimum value in the salary_hour_avg column and then use iloc to get the corresponding row.

# %%
df.iloc[df['salary_hour_avg'].idxmin()][['job_title_short', 'salary_hour_avg']]
# Out:
# job_title_short    Data Scientist
# salary_hour_avg               8.0
# Name: 88185, dtype: object

# %% [markdown]
# 🟨 Job Count by Country (1.26.5) - Problem
# Pandas Analysis
# Problem Statement:
#
# Group the DataFrame by job_country and calculate the total number of job postings for each country. Display the result.
# Hint:
#
# Use the groupby method to group the DataFrame by job_country and then use the size method to count the number of job postings for each group.

# %%
df.groupby('job_country')['job_country'].count()
#df.groupby('job_country').size()
# Out:
# job_country
# Afghanistan      16
# Albania         119
# Algeria         111
# Angola           11
# Argentina      8736
#                ...
# Venezuela        69
# Vietnam        2414
# Yemen            10
# Zambia          104
# Zimbabwe         81
# Length: 160, dtype: int64

# %% [markdown]
# 🟩 Simple Line Plot (1.28.1) - Problem
# Matplotlib Intro
# Problem Statement:
#
# Create a simple line plot with the pyplot module of matplotlib, using the number of job postings over the first 4 months of the year. Use the months as the x-axis and the number of postings as the y-axis. Below are the given variables.
# Code Needed:
#
# months = ['January', 'February', 'March', 'April']
# postings = [120, 150, 100, 130]
#
# Hint:
#
# Use the plt.plot() function to create the line plot.

# %%
import matplotlib.pyplot as plt

months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]
plt.plot(postings,months)

# %% [markdown]
# 🟩 Bar Chart (1.28.2) - Problem
# Matplotlib Intro
# Problem Statement:
#
# Create a bar chart showing the number of job postings for different job titles. Below are the given variables for the job_titles and the associated number of job postings.
# Code Needed:
#
# job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
# postings = [50, 75, 60]
#
# Hint:
#
# Use the plt.bar() function to create the bar chart.

# %%
job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
postings = [50, 75, 60]

plt.bar(job_titles, postings)
# Out:
# <BarContainer object of 3 artists>

# %%
# !pip install datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup (not needed for all problems but good to do anyways)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# 🟩 Job Country Bar Chart (1.29.1) - Problem
# Matplotlib Plotting
# Problem Statement:
#
# Create a bar chart showing the number of job postings for the job_country. Use the job_country column and count the number of postings for each location. Only get the top 5 job countries. Additionally, change the color of the bars to 'orange'.
# Hint:
#
# Use the plt.bar() function to create the bar chart.

# %%
job_for_country= df.job_country.value_counts().head(5)
plt.bar(job_for_country.index, job_for_country.values, color='orange')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 🟨 Average Salary Horizontal Bar Chart (1.29.2) - Problem
# Matplotlib Plotting
# Problem Statement:
#
# Create a horizontal bar chart showing the average yearly salary for different job titles. Use the job_title_short and salary_year_avg columns to calculate the average salary for each job title.
# Hint:
#
# Use the plt.barh() function to create the horizontal bar chart.

# %%
avg_salary = df.groupby('job_title_short')['salary_year_avg'].mean().astype(int)
avg_salary.sort_values(ascending=True, inplace=True)
plt.barh(avg_salary.index ,avg_salary.values)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# 🟥 Average Salary Trend Line Plot (1.29.3) - Problem
# Matplotlib Plotting
# Problem Statement:
#
# Create a line plot showing the trend of average yearly salary over the months of the year. Use the job_posted_date column to extract the month and calculate the average salary for each month.
# Hint:
#
# Use the plt.plot() function to create the line plot.

# %%
import calendar

month_count = df.job_posted_date.dt.month.value_counts()
month_count.sort_index(ascending=True, inplace=True)
month_count.index = month_count.index.map(lambda x: calendar.month_name[x])

plt.plot(month_count.index,month_count.values)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 🟩 Bar Chart with Labels (1.30.1) - Problem
# Matplotlib Labeling
# Problem Statement:
#
# Using the same bar chart created in Matplotlib Plotting Question #1 showing the number of job postings for the job_country:
#
#     Use the job_country column and count the number of postings for each location. Only get the top 5 job countries.
#     Add labels for the x-axis (label as 'Country'), y-axis (label as 'Number of Postings'), and a title (set as 'Number of Jobs per Country') for the chart.
#     Rotate the x-axis labels by 45 degrees and align them to the right.
#
# Hint:
#
# Use the plt.bar() function to create the bar chart and plt.xlabel(), plt.ylabel(), plt.title(), and plt.xticks() to add labels and titles.

# %%
job_numbers_by_loc = df['job_country'].value_counts().head(5)
plt.bar(job_numbers_by_loc.index, job_numbers_by_loc.values)
plt.xlabel('Country')
plt.ylabel('Number of Postings')
plt.title('Number of Jobs per Country')
plt.xticks(rotation=45, ha='center')
plt.show()

# %% [markdown]
# 🟨 Horizontal Bar Chart with Labels (1.30.2) - Problem
# Matplotlib Labeling
# Problem Statement:
#
# Using the same bar chart created in Matplotlib Plotting Question #2 showing the average yearly salary for different job titles:
#
#     Use the 'job_title_short' and salary_year_avg columns to calculate the average salary for each job title.
#     Add labels for the x-axis (label as 'Average Salary') and a title (set as 'Average Salary by Job Title') for the plot.
#
# Hint:
#
# Use the plt.barh() function to create the horizontal bar plot and plt.xlabel() and plt.title() to add labels and titles.

# %%
avg_salary = df.groupby('job_title_short')['salary_year_avg'].mean()
avg_salary.sort_values(ascending = True, inplace = True)
plt.barh(avg_salary.index,avg_salary.values)
plt.xlabel('Average Salary')
plt.title('Average Salary by Job Title')
plt.show()

# %% [markdown]
# 🟥 Line Chart with Labels (1.30.3) - Problem
# Matplotlib Labeling
# Problem Statement:
#
# Using the same line plot created in Matplotlib Plotting Question #3 showing the trend of average yearly salary over the first 6 months of the year:
#
#     Use the job_posted_date column to extract the month and calculate the average salary for each month.
#     Add labels for the x-axis (label as 'Month'), y-axis (label as 'Average Salary'), and a title (set as 'Average Salary by Job Month') for the plot.
#     Change the line color to 'red' and add a legend to the plot.
#
# Hint:
#
# Use the plt.plot() function to create the line plot and plt.xlabel(), plt.ylabel(), plt.title(), and plt.legend() to add labels, title, and legend.

# %%
import calendar

df['job_posted_month'] = df['job_posted_date'].dt.month
df = df.sort_values('job_posted_month')
df_6first = df[df['job_posted_month'] <=6]
avg_yearly_salary_by_month = df_6first.groupby('job_posted_month')['salary_year_avg'].mean()
month_names = [calendar.month_name[m] for m in avg_yearly_salary_by_month.index]
plt.plot(avg_yearly_salary_by_month.index, avg_yearly_salary_by_month.values, color='red', label='Average Salary')
plt.xlabel('Month')
plt.ylabel('Average Salary')
plt.title('Average Salary by Job Month')
plt.legend()
plt.show()

# %% [markdown]
# 🟩 Job Posting Location Bar Plot (1.31.1) - Problem
# Matplotlib Pandas Plotting
# Problem Statement:
#
# Create a bar plot with the Pandas .plot() method showing the top 5 job posting platforms (e.g., LinkedIn, Upwork, etc.) with the highest number of job postings. Use the job_via column to count the number of postings for each platform.
# Hint:
#
# Use the plot() method of either a Pandas DataFrame or Series object to plot this. Do NOT use the plt.bar() function.

# %%
best_platform = df.job_via.value_counts().head(5)
best_platform.plot(kind='bar')
plt.xlabel('')
plt.xticks(rotation=45, ha='center')
plt.show()

# %% [markdown]
# 🟩 Top Job Locations (1.31.2) - Problem
# Matplotlib Pandas Plotting
# Problem Statement:
#
# Create a horizontal bar plot showing the top 5 job locations with the highest number of job postings:
#
#     Use the job_location column to count the number of postings for each location.
#     Add in labels for the x-axis (label as 'Count of Jobs'), y-axis (label as 'Job Location'), and a title (set as 'Number of Job Postings by Job Location') for the chart.
#
# Hint:
#
# Use the plot() method of the Pandas Series to create the horizontal bar plot.

# %%
job_counts_by_loc = df['job_location'].value_counts().head(5).sort_values(ascending=True)
job_counts_by_loc.plot(kind='barh')
plt.xlabel('Count of Jobs')
plt.ylabel('Job Location')
plt.title('Number of Job Postings by Job Location')
plt.show()

# %% [markdown]
# 🟨 Job Postings Trend Line Plot (1.31.3) - Problem
# Matplotlib Pandas Plotting
# Problem Statement:
#
# Create a line plot showing the trend of job postings over time using the Pandas method to plot:
#
#     Create a DataFrame called monthly_job_counts and use the job_posted_date column to count the number of job postings for each month (in the format 'Jan').
#     Add labels for the x-axis (label as 'Month'), y-axis (label as 'Number of Job Postings'), and a title (set as 'Trend of Job Postings Over Time') for the chart.
#
# Hint:
#
# Use the plot() method of either a Pandas DataFrame or Series object to plot this. Do NOT use the plt.plot() function.

# %%
'''

import calendar

monthly_job_counts = df.job_posted_date.dt.month.value_counts().sort_index()
monthly_job_counts.index = [calendar.month_abbr[m] for m in monthly_job_counts.index]
monthly_job_counts.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
'''

df['job_posted_month'] = df['job_posted_date'].dt.to_period('M')
monthly_job_counts = df['job_posted_month'].value_counts().sort_index()
monthly_job_counts.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
plt.show()
